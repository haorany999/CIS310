# %% [markdown]
# # Term Project: Data Preparation And Analysis For Washington D.C Properties
# # Total Points: 60
#
# ## Instructions:
#
# 1) Rename this .ipynb file with your first and last name (For Both Team members)
#
# 2) Complete the project info form
#
# 3) Answer all the questions
#
# 4) Upload this file into Canvas as your submisison file for the project
#
# **Do not upload/push this file into your GitHub account**
#
# ** The CSV Dataset File 'DC_Properties.csv' is Eclosed with This .ipynb file **

# %% [markdown]
# # Complete the file info form:
#
# Team Names Full Name1: ------Haoran Yang-----------------  Full Name2: --------No-----------
#
# Team CSU ID1: -----831827060---------- Team CSU ID2: --------No-------------
#
# Date:--------05/04/2021----------------

# %% [markdown]
# ## Dataset Attribute Description
#
# - BATHRM - Number of Full Bathrooms
# - HF_BATHRM - Number of Half Bathrooms (no bathtub or shower)
# - HEAT - Heating
# - AC - Cooling
# - NUM_UNITS - Number of Units
# - ROOMS - Number of Rooms
# - BEDRM - Number of Bedrooms
# - AYB - The earliest time the main portion of the building was built
# - YR_RMDL - Year structure was remodeled
# - EYB - The year an improvement was built more recent than actual year built
# - STORIES - Number of stories in primary dwelling
# - SALEDATE - Date of most recent sale
# - PRICE - Price of most recent sale
# - QUALIFIED - Qualified
# - SALE_NUM - Sale Number
# - GBA - Gross building area in square feet
# - BLDG_NUM - Building Number on Property
# - STYLE - Structure style in regard to stories
# - STRUCT - Structure type
# - GRADE - Structural Grade
# - CNDTN - Condition
# - EXTWALL - Extrerior wall type
# - ROOF - Roof type
# - INTWALL - Interior wall
# - KITCHENS - Number of kitchens
# - FIREPLACES - Number of fireplaces
# - USECODE - Property use code
# - LANDAREA - Land area of property in square feet
# - GIS_LAST_MOD_DTTM - Last Modified Date
# - SOURCE - Raw Data Source
# - CMPLX_NUM - Complex number
# - LIVING_GBA - Gross building area in square feet
# - FULLADDRESS - Full Street Address
# - CITY - City
# - STATE - State
# - ZIPCODE - Zip Code
# - NATIONALGRID - Address location national grid coordinate spatial address
# - LATITUDE - Latitude
# - LONGITUDE - Longitude
# - ASSESSMENT_NBHD - Neighborhood ID
# - ASSESSMENT_SUBNBHD - Subneighborhood ID
# - CENSUS_TRACT - Census tract
# - CENSUS_BLOCK - Census block
# - WARD - Ward (District is divided into eight wards, each with approximately 75,000 residents)
# - SQUARE - Square (from SSL)
# - X - longitude
# - Y - latitude
# - QUADRANT - City quadrant (NE, SE, SW, NW)

# %%
#Let's go ahead and start with some imports
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# For time stamps
from datetime import datetime

# Optionally add any modules as you need

# %% [markdown]
# ## Q1 (3 points): Read the Washington D.C property Dataset from file?

# %%
# Q1 Anaswer:
data = pd.read_csv('DC_Properties.csv')

# %% [markdown]
# ## Q2 (17 Points): Data Exploration?
#  - Find the total number of observations (Rows) (3 pts)
#  - Find the total number of variables (columns) (3 pts)
#  - Find the number of numerical and none-numerical variables (6 pts)
#  - Find the number of variables (columns) that include missing values (5 pts)
#
#  ** One way to find out the number of observations/variables (columns) and the variables types is to use DataFrame.info() **

# %%
# Q2 Anaswers: (Add Cells as needed)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28900 entries, 0 to 28899
# Data columns (total 47 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          28900 non-null  int64
#  1   BATHRM              28900 non-null  int64
#  2   HF_BATHRM           28900 non-null  int64
#  3   HEAT                28900 non-null  object
#  4   AC                  28900 non-null  object
#  5   NUM_UNITS           28900 non-null  int64
#  6   ROOMS               28900 non-null  int64
#  7   BEDRM               28900 non-null  int64
#  8   AYB                 28900 non-null  int64
#  9   YR_RMDL             28900 non-null  int64
#  10  EYB                 28900 non-null  int64
#  11  STORIES             28900 non-null  float64
#  12  SALEDATE            28900 non-null  object
#  13  PRICE               28891 non-null  float64
#  14  QUALIFIED           28900 non-null  object
#  15  SALE_NUM            28900 non-null  int64
#  16  GBA                 28900 non-null  int64
#  17  BLDG_NUM            28900 non-null  int64
#  18  STYLE               28900 non-null  object
#  19  STRUCT              28900 non-null  object
#  20  GRADE               28900 non-null  object
#  21  CNDTN               28900 non-null  object
#  22  EXTWALL             28900 non-null  object
#  23  ROOF                28900 non-null  object
#  24  INTWALL             28900 non-null  object
#  25  KITCHENS            28900 non-null  int64
#  26  FIREPLACES          28900 non-null  int64
#  27  USECODE             28900 non-null  int64
#  28  LANDAREA            28900 non-null  int64
#  29  GIS_LAST_MOD_DTTM   28900 non-null  object
#  30  SOURCE              28900 non-null  object
#  31  FULLADDRESS         28900 non-null  object
#  32  CITY                28900 non-null  object
#  33  STATE               28900 non-null  object
#  34  ZIPCODE             28900 non-null  int64
#  35  NATIONALGRID        28900 non-null  object
#  36  LATITUDE            28900 non-null  float64
#  37  LONGITUDE           28900 non-null  float64
#  38  ASSESSMENT_NBHD     28900 non-null  object
#  39  ASSESSMENT_SUBNBHD  28900 non-null  object
#  40  CENSUS_TRACT        28900 non-null  int64
#  41  CENSUS_BLOCK        28900 non-null  object
#  42  WARD                28900 non-null  object
#  43  SQUARE              28900 non-null  int64
#  44  X                   28900 non-null  float64
#  45  Y                   28900 non-null  float64
#  46  QUADRANT            28900 non-null  object
# dtypes: float64(6), int64(19), object(22)
# memory usage: 10.4+ MB

# %%
data.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y          2      8      4
# 1           1       3          1  Hot Water Rad  Y          2      9      5
# 2           2       3          1  Hot Water Rad  Y          2      8      5
# 3           3       3          1  Hot Water Rad  Y          2      8      4
# 4           4       3          1      Warm Cool  Y          2      7      3
#
#     AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910     1988  ... -77.040832       Old City 2   040 D Old City 2
# 1  1910     2009  ... -77.040678       Old City 2   040 D Old City 2
# 2  1900     2003  ... -77.040629       Old City 2   040 D Old City 2
# 3  1906     2011  ... -77.040129       Old City 2   040 D Old City 2
# 4  1908     2008  ... -77.039903       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# 0          4201  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 1          4201  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 2          4201  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 3          4201  004201 2005  Ward 2     152 -77.040429  38.914881       NW
# 4          4201  004201 2005  Ward 2     152 -77.040429  38.914881       NW
#
# [5 rows x 47 columns]

# %%
data.tail()
# Out:
#        Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 28895       28895       3          0  Forced Air  N          3     13      8
# 28896       28896       3          0  Forced Air  N          3     14      6
# 28897       28897       2          0  Forced Air  Y          2     10      4
# 28898       28898       2          0  Forced Air  N          2     10      4
# 28899       28899       2          0  Forced Air  Y          2     10      4
#
#         AYB  YR_RMDL  ...  LONGITUDE   ASSESSMENT_NBHD  \
# 28895  1953     2016  ... -77.006996  Congress Heights
# 28896  1953     1999  ... -77.006997  Congress Heights
# 28897  1953     2017  ... -77.006034  Congress Heights
# 28898  1953     2017  ... -77.006528  Congress Heights
# 28899  1953     2018  ... -77.006571  Congress Heights
#
#            ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# 28895  016 A Congress Heights         10900  010900 2000  Ward 8    6254
# 28896  016 A Congress Heights         10900  010900 2000  Ward 8    6254
# 28897  016 A Congress Heights         10900  010900 2000  Ward 8    6254
# 28898  016 A Congress Heights         10900  010900 2000  Ward 8    6254
# 28899  016 A Congress Heights         10900  010900 2000  Ward 8    6254
#
#                X          Y QUADRANT
# 28895 -77.006347  38.821799       SW
# 28896 -77.006347  38.821799       SW
# 28897 -77.006347  38.821799       SW
# 28898 -77.006347  38.821799       SW
# 28899 -77.006347  38.821799       SW
#
# [5 rows x 47 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'FULLADDRESS',
#        'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID', 'LATITUDE', 'LONGITUDE',
#        'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT', 'CENSUS_BLOCK',
#        'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
from pandas.api.types import is_numeric_dtype

n=0

for c in data.columns:
    if is_numeric_dtype(data[c]):
        n+=1
        
print('numerical variables: ', n, 'Non-numerial variables: ', len(data.columns)-n)
# Out:
# numerical variables:  25 Non-numerial variables:  22

# %%
# missing value
data.isnull()
# Out:
#        Unnamed: 0  BATHRM  HF_BATHRM   HEAT     AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           False   False      False  False  False      False  False  False
# 1           False   False      False  False  False      False  False  False
# 2           False   False      False  False  False      False  False  False
# 3           False   False      False  False  False      False  False  False
# 4           False   False      False  False  False      False  False  False
# ...           ...     ...        ...    ...    ...        ...    ...    ...
# 28895       False   False      False  False  False      False  False  False
# 28896       False   False      False  False  False      False  False  False
# 28897       False   False      False  False  False      False  False  False
# 28898       False   False      False  False  False      False  False  False
# 28899       False   False      False  False  False      False  False  False
#
#          AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0      False    False  ...      False            False               False
# 1      False    False  ...      False            False               False
# 2      False    False  ...      False            False               False
# 3      False    False  ...      False            False               False
# 4      False    False  ...      False            False               False
# ...      ...      ...  ...        ...              ...                 ...
# 28895  False    False  ...      False            False               False
# 28896  False    False  ...      False            False               False
# 28897  False    False  ...      False            False               False
# 28898  False    False  ...      False            False               False
# 28899  False    False  ...      False            False               False
#
#        CENSUS_TRACT  CENSUS_BLOCK   WARD  SQUARE      X      Y  QUADRANT
# 0             False         False  False   False  False  False     False
# 1             False         False  False   False  False  False     False
# 2             False         False  False   False  False  False     False
# 3             False         False  False   False  False  False     False
# 4             False         False  False   False  False  False     False
# ...             ...           ...    ...     ...    ...    ...       ...
# 28895         False         False  False   False  False  False     False
# 28896         False         False  False   False  False  False     False
# 28897         False         False  False   False  False  False     False
# 28898         False         False  False   False  False  False     False
# 28899         False         False  False   False  False  False     False
#
# [28900 rows x 47 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# BATHRM                0
# HF_BATHRM             0
# HEAT                  0
# AC                    0
# NUM_UNITS             0
# ROOMS                 0
# BEDRM                 0
# AYB                   0
# YR_RMDL               0
# EYB                   0
# STORIES               0
# SALEDATE              0
# PRICE                 9
# QUALIFIED             0
# SALE_NUM              0
# GBA                   0
# BLDG_NUM              0
# STYLE                 0
# STRUCT                0
# GRADE                 0
# CNDTN                 0
# EXTWALL               0
# ROOF                  0
# INTWALL               0
# KITCHENS              0
# FIREPLACES            0
# USECODE               0
# LANDAREA              0
# GIS_LAST_MOD_DTTM     0
# SOURCE                0
# FULLADDRESS           0
# CITY                  0
# STATE                 0
# ZIPCODE               0
# NATIONALGRID          0
# LATITUDE              0
# LONGITUDE             0
# ASSESSMENT_NBHD       0
# ASSESSMENT_SUBNBHD    0
# CENSUS_TRACT          0
# CENSUS_BLOCK          0
# WARD                  0
# SQUARE                0
# X                     0
# Y                     0
# QUADRANT              0
# dtype: int64

# %% [markdown]
# ## Q3 (20 Points): Preparing data for analytics?
# - Handling all missing values in the data set by removing records with np.nan values. (5 pts)
# - Remove the properties that have abnormal price. (5 pts)
# - Remove all columns that have a constant value. (5 pts)
# - Replace the column SALEDATE with the columns, SALEYEAR and SALEMONTH (5 pts)

# %%
# Q3 Anaswers: (Add Cells as needed)
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# BATHRM                0
# HF_BATHRM             0
# HEAT                  0
# AC                    0
# NUM_UNITS             0
# ROOMS                 0
# BEDRM                 0
# AYB                   0
# YR_RMDL               0
# EYB                   0
# STORIES               0
# SALEDATE              0
# PRICE                 0
# QUALIFIED             0
# SALE_NUM              0
# GBA                   0
# BLDG_NUM              0
# STYLE                 0
# STRUCT                0
# GRADE                 0
# CNDTN                 0
# EXTWALL               0
# ROOF                  0
# INTWALL               0
# KITCHENS              0
# FIREPLACES            0
# USECODE               0
# LANDAREA              0
# GIS_LAST_MOD_DTTM     0
# SOURCE                0
# FULLADDRESS           0
# CITY                  0
# STATE                 0
# ZIPCODE               0
# NATIONALGRID          0
# LATITUDE              0
# LONGITUDE             0
# ASSESSMENT_NBHD       0
# ASSESSMENT_SUBNBHD    0
# CENSUS_TRACT          0
# CENSUS_BLOCK          0
# WARD                  0
# SQUARE                0
# X                     0
# Y                     0
# QUADRANT              0
# dtype: int64

# %%
# abnormal removing:
data['PRICE'].plot(kind='hist', bins = 50)

# %%
data['PRICE'].plot(kind='hist', bins =200)

# %%
data['PRICE'].min()
# Out:
# 1.0

# %%
data['PRICE'].max()
# Out:
# 23960287.0

# %%
data['PRICE'].sort_values(ascending = True).head(20)
# Out:
# 28896       1.0
# 8174       10.0
# 16138     250.0
# 17936     250.0
# 17882     250.0
# 24198     250.0
# 15819     250.0
# 14323     250.0
# 28185     250.0
# 17622     500.0
# 1130      936.0
# 27885    1000.0
# 1496     1377.0
# 28152    4101.0
# 17898    5000.0
# 23254    5000.0
# 27048    5522.0
# 20956    5964.0
# 26344    7716.0
# 26993    9497.0
# Name: PRICE, dtype: float64

# %%
data = data[data['PRICE']>200]
data.shape
# Out:
# (28889, 47)

# %%
data['PRICE'].sort_values(ascending = True).head(20)
# Out:
# 14323      250.0
# 17936      250.0
# 16138      250.0
# 15819      250.0
# 28185      250.0
# 24198      250.0
# 17882      250.0
# 17622      500.0
# 1130       936.0
# 27885     1000.0
# 1496      1377.0
# 28152     4101.0
# 17898     5000.0
# 23254     5000.0
# 27048     5522.0
# 20956     5964.0
# 26344     7716.0
# 26993     9497.0
# 21765    10000.0
# 28812    11000.0
# Name: PRICE, dtype: float64

# %%
constant_columns = []
for c in data.columns:
    n = len(data[c].unique())
    if n==1 :
        constant_columns.append(c)
        
print('Constant Columns: ', constant_columns)
# Out:
# Constant Columns:  ['GIS_LAST_MOD_DTTM', 'SOURCE', 'CITY', 'STATE']

# %%
data.drop(columns = constant_columns, axis = 1, inplace = True)
data
# Out:
#        Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0               0       4          0      Warm Cool  Y          2      8
# 1               1       3          1  Hot Water Rad  Y          2      9
# 2               2       3          1  Hot Water Rad  Y          2      8
# 3               3       3          1  Hot Water Rad  Y          2      8
# 4               4       3          1      Warm Cool  Y          2      7
# ...           ...     ...        ...            ... ..        ...    ...
# 28894       28894       3          0     Forced Air  N          3     12
# 28895       28895       3          0     Forced Air  N          3     13
# 28897       28897       2          0     Forced Air  Y          2     10
# 28898       28898       2          0     Forced Air  N          2     10
# 28899       28899       2          0     Forced Air  Y          2     10
#
#        BEDRM   AYB  YR_RMDL  ...  LONGITUDE   ASSESSMENT_NBHD  \
# 0          4  1910     1988  ... -77.040832        Old City 2
# 1          5  1910     2009  ... -77.040678        Old City 2
# 2          5  1900     2003  ... -77.040629        Old City 2
# 3          4  1906     2011  ... -77.040129        Old City 2
# 4          3  1908     2008  ... -77.039903        Old City 2
# ...      ...   ...      ...  ...        ...               ...
# 28894      6  1954     2002  ... -77.007013  Congress Heights
# 28895      8  1953     2016  ... -77.006996  Congress Heights
# 28897      4  1953     2017  ... -77.006034  Congress Heights
# 28898      4  1953     2017  ... -77.006528  Congress Heights
# 28899      4  1953     2018  ... -77.006571  Congress Heights
#
#            ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# 0            040 D Old City 2          4201  004201 2006  Ward 2     152
# 1            040 D Old City 2          4201  004201 2006  Ward 2     152
# 2            040 D Old City 2          4201  004201 2006  Ward 2     152
# 3            040 D Old City 2          4201  004201 2005  Ward 2     152
# 4            040 D Old City 2          4201  004201 2005  Ward 2     152
# ...                       ...           ...          ...     ...     ...
# 28894  016 A Congress Heights         10900  010900 2000  Ward 8    6254
# 28895  016 A Congress Heights         10900  010900 2000  Ward 8    6254
# 28897  016 A Congress Heights         10900  010900 2000  Ward 8    6254
# 28898  016 A Congress Heights         10900  010900 2000  Ward 8    6254
# 28899  016 A Congress Heights         10900  010900 2000  Ward 8    6254
#
#                X          Y QUADRANT
# 0     -77.040429  38.914881       NW
# 1     -77.040429  38.914881       NW
# 2     -77.040429  38.914881       NW
# 3     -77.040429  38.914881       NW
# 4     -77.040429  38.914881       NW
# ...          ...        ...      ...
# 28894 -77.006347  38.821799       SW
# 28895 -77.006347  38.821799       SW
# 28897 -77.006347  38.821799       SW
# 28898 -77.006347  38.821799       SW
# 28899 -77.006347  38.821799       SW
#
# [28889 rows x 43 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28889 entries, 0 to 28899
# Data columns (total 43 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          28889 non-null  int64
#  1   BATHRM              28889 non-null  int64
#  2   HF_BATHRM           28889 non-null  int64
#  3   HEAT                28889 non-null  object
#  4   AC                  28889 non-null  object
#  5   NUM_UNITS           28889 non-null  int64
#  6   ROOMS               28889 non-null  int64
#  7   BEDRM               28889 non-null  int64
#  8   AYB                 28889 non-null  int64
#  9   YR_RMDL             28889 non-null  int64
#  10  EYB                 28889 non-null  int64
#  11  STORIES             28889 non-null  float64
#  12  SALEDATE            28889 non-null  object
#  13  PRICE               28889 non-null  float64
#  14  QUALIFIED           28889 non-null  object
#  15  SALE_NUM            28889 non-null  int64
#  16  GBA                 28889 non-null  int64
#  17  BLDG_NUM            28889 non-null  int64
#  18  STYLE               28889 non-null  object
#  19  STRUCT              28889 non-null  object
#  20  GRADE               28889 non-null  object
#  21  CNDTN               28889 non-null  object
#  22  EXTWALL             28889 non-null  object
#  23  ROOF                28889 non-null  object
#  24  INTWALL             28889 non-null  object
#  25  KITCHENS            28889 non-null  int64
#  26  FIREPLACES          28889 non-null  int64
#  27  USECODE             28889 non-null  int64
#  28  LANDAREA            28889 non-null  int64
#  29  FULLADDRESS         28889 non-null  object
#  30  ZIPCODE             28889 non-null  int64
#  31  NATIONALGRID        28889 non-null  object
#  32  LATITUDE            28889 non-null  float64
#  33  LONGITUDE           28889 non-null  float64
#  34  ASSESSMENT_NBHD     28889 non-null  object
#  35  ASSESSMENT_SUBNBHD  28889 non-null  object
#  36  CENSUS_TRACT        28889 non-null  int64
#  37  CENSUS_BLOCK        28889 non-null  object
#  38  WARD                28889 non-null  object
#  39  SQUARE              28889 non-null  int64
#  40  X                   28889 non-null  float64
#  41  Y                   28889 non-null  float64
#  42  QUADRANT            28889 non-null  object
# dtypes: float64(6), int64(19), object(18)
# memory usage: 9.7+ MB

# %%
dataObject = pd.DatetimeIndex(data['SALEDATE'])

# %%
dataObject
# Out:
# DatetimeIndex(['2003-11-25', '2016-06-21', '2006-07-12', '2011-09-29',
#                '2018-05-03', '2010-11-04', '2001-07-23', '2016-01-12',
#                '2006-01-09', '2012-08-21',
#                ...
#                '2007-03-28', '2014-05-27', '2008-09-26', '2013-09-04',
#                '2012-12-21', '2002-08-28', '2000-11-20', '2016-06-27',
#                '2017-07-27', '2017-11-08'],
#               dtype='datetime64[ns]', name='SALEDATE', length=28889, freq=None)

# %%
data['SALEYEAR'] = dataObject.year
data['SALEMONTH'] = dataObject.month

data
# Out:
#        Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0               0       4          0      Warm Cool  Y          2      8
# 1               1       3          1  Hot Water Rad  Y          2      9
# 2               2       3          1  Hot Water Rad  Y          2      8
# 3               3       3          1  Hot Water Rad  Y          2      8
# 4               4       3          1      Warm Cool  Y          2      7
# ...           ...     ...        ...            ... ..        ...    ...
# 28894       28894       3          0     Forced Air  N          3     12
# 28895       28895       3          0     Forced Air  N          3     13
# 28897       28897       2          0     Forced Air  Y          2     10
# 28898       28898       2          0     Forced Air  N          2     10
# 28899       28899       2          0     Forced Air  Y          2     10
#
#        BEDRM   AYB  YR_RMDL  ...      ASSESSMENT_SUBNBHD  CENSUS_TRACT  \
# 0          4  1910     1988  ...        040 D Old City 2          4201
# 1          5  1910     2009  ...        040 D Old City 2          4201
# 2          5  1900     2003  ...        040 D Old City 2          4201
# 3          4  1906     2011  ...        040 D Old City 2          4201
# 4          3  1908     2008  ...        040 D Old City 2          4201
# ...      ...   ...      ...  ...                     ...           ...
# 28894      6  1954     2002  ...  016 A Congress Heights         10900
# 28895      8  1953     2016  ...  016 A Congress Heights         10900
# 28897      4  1953     2017  ...  016 A Congress Heights         10900
# 28898      4  1953     2017  ...  016 A Congress Heights         10900
# 28899      4  1953     2018  ...  016 A Congress Heights         10900
#
#       CENSUS_BLOCK    WARD SQUARE          X          Y  QUADRANT SALEYEAR  \
# 0      004201 2006  Ward 2    152 -77.040429  38.914881        NW     2003
# 1      004201 2006  Ward 2    152 -77.040429  38.914881        NW     2016
# 2      004201 2006  Ward 2    152 -77.040429  38.914881        NW     2006
# 3      004201 2005  Ward 2    152 -77.040429  38.914881        NW     2011
# 4      004201 2005  Ward 2    152 -77.040429  38.914881        NW     2018
# ...            ...     ...    ...        ...        ...       ...      ...
# 28894  010900 2000  Ward 8   6254 -77.006347  38.821799        SW     2002
# 28895  010900 2000  Ward 8   6254 -77.006347  38.821799        SW     2000
# 28897  010900 2000  Ward 8   6254 -77.006347  38.821799        SW     2016
# 28898  010900 2000  Ward 8   6254 -77.006347  38.821799        SW     2017
# 28899  010900 2000  Ward 8   6254 -77.006347  38.821799        SW     2017
#
#       SALEMONTH
# 0            11
# 1             6
# 2             7
# 3             9
# 4             5
# ...         ...
# 28894         8
# 28895        11
# 28897         6
# 28898         7
# 28899        11
#
# [28889 rows x 45 columns]

# %%
data[['SALEDATE','SALEYEAR','SALEMONTH']]
# Out:
#          SALEDATE  SALEYEAR  SALEMONTH
# 0      11/25/2003      2003         11
# 1       6/21/2016      2016          6
# 2       7/12/2006      2006          7
# 3       9/29/2011      2011          9
# 4        5/3/2018      2018          5
# ...           ...       ...        ...
# 28894   8/28/2002      2002          8
# 28895  11/20/2000      2000         11
# 28897   6/27/2016      2016          6
# 28898   7/27/2017      2017          7
# 28899   11/8/2017      2017         11
#
# [28889 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28889 entries, 0 to 28899
# Data columns (total 45 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          28889 non-null  int64
#  1   BATHRM              28889 non-null  int64
#  2   HF_BATHRM           28889 non-null  int64
#  3   HEAT                28889 non-null  object
#  4   AC                  28889 non-null  object
#  5   NUM_UNITS           28889 non-null  int64
#  6   ROOMS               28889 non-null  int64
#  7   BEDRM               28889 non-null  int64
#  8   AYB                 28889 non-null  int64
#  9   YR_RMDL             28889 non-null  int64
#  10  EYB                 28889 non-null  int64
#  11  STORIES             28889 non-null  float64
#  12  SALEDATE            28889 non-null  object
#  13  PRICE               28889 non-null  float64
#  14  QUALIFIED           28889 non-null  object
#  15  SALE_NUM            28889 non-null  int64
#  16  GBA                 28889 non-null  int64
#  17  BLDG_NUM            28889 non-null  int64
#  18  STYLE               28889 non-null  object
#  19  STRUCT              28889 non-null  object
#  20  GRADE               28889 non-null  object
#  21  CNDTN               28889 non-null  object
#  22  EXTWALL             28889 non-null  object
#  23  ROOF                28889 non-null  object
#  24  INTWALL             28889 non-null  object
#  25  KITCHENS            28889 non-null  int64
#  26  FIREPLACES          28889 non-null  int64
#  27  USECODE             28889 non-null  int64
#  28  LANDAREA            28889 non-null  int64
#  29  FULLADDRESS         28889 non-null  object
#  30  ZIPCODE             28889 non-null  int64
#  31  NATIONALGRID        28889 non-null  object
#  32  LATITUDE            28889 non-null  float64
#  33  LONGITUDE           28889 non-null  float64
#  34  ASSESSMENT_NBHD     28889 non-null  object
#  35  ASSESSMENT_SUBNBHD  28889 non-null  object
#  36  CENSUS_TRACT        28889 non-null  int64
#  37  CENSUS_BLOCK        28889 non-null  object
#  38  WARD                28889 non-null  object
#  39  SQUARE              28889 non-null  int64
#  40  X                   28889 non-null  float64
#  41  Y                   28889 non-null  float64
#  42  QUADRANT            28889 non-null  object
#  43  SALEYEAR            28889 non-null  int64
#  44  SALEMONTH           28889 non-null  int64
# dtypes: float64(6), int64(21), object(18)
# memory usage: 10.1+ MB

# %% [markdown]
# ## Q4 (20 Points). Use data visualization for data analysis
# - Show the trend of average sale-price over years. (5 pts)
# - Show the number of properties that have been sold over months. (5 pts)
# - Show the sum of sale price for all 4 quadrant in Washington D.C. (5 pts)
# - Plot the average sale price over the number of fireplaces for properties that exist within NW and were sold in 2015. (5 pts)

# %%
# Q4 Anaswers: (Add Cells as needed)
data[['SALEYEAR','PRICE']].groupby('SALEYEAR').sum()
# Out:
#                  PRICE
# SALEYEAR
# 1986      8.900000e+04
# 1990      1.100000e+05
# 1991      1.899000e+05
# 1992      5.757214e+07
# 1993      4.429754e+07
# 1994      5.628526e+07
# 1995      5.398630e+07
# 1996      7.035789e+07
# 1997      9.482384e+07
# 1998      9.565255e+07
# 1999      1.344895e+08
# 2000      1.857419e+08
# 2001      2.202768e+08
# 2002      2.967752e+08
# 2003      3.910785e+08
# 2004      5.358059e+08
# 2005      6.898010e+08
# 2006      5.892908e+08
# 2007      7.028348e+08
# 2008      5.607641e+08
# 2009      6.594470e+08
# 2010      8.724163e+08
# 2011      9.663782e+08
# 2012      1.104213e+09
# 2013      1.398717e+09
# 2014      1.613042e+09
# 2015      1.792144e+09
# 2016      1.955341e+09
# 2017      2.485233e+09
# 2018      1.291965e+09

# %%
data[['SALEYEAR','PRICE']].groupby('SALEYEAR').sum().plot(figsize = (8,6), y ='PRICE', fontsize = 12,
                                                          title="Sale's price over Years")
plt.ylabel("Sale's Prices")
# Out:
# Text(0, 0.5, "Sale's Prices")

# %%
data[['SALEMONTH','SALE_NUM']].groupby('SALEMONTH').sum().plot(figsize = (8,6), y ='SALE_NUM', fontsize = 12,
                                                          title="Properties Sold Over Month")
plt.ylabel("SOLD over Month")
# Out:
# Text(0, 0.5, 'SOLD over Month')

# %%
data[['QUADRANT','PRICE']].groupby('QUADRANT').sum().plot(figsize = (10,8), y ='PRICE', fontsize = 12,
                                                          title="Price for 4 Quadrant in DC")
plt.ylabel("Sale Prices")
# Out:
# Text(0, 0.5, 'Sale Prices')

# %%
filter1 = data[data['SALEYEAR']==2015]
len(filter1)
# Out:
# 2257

# %%
filter2 = data[data['QUADRANT']=='NW']
len(filter2)
# Out:
# 13824

# %%
filter2 = data['QUADRANT']== 'NW'

# %%
filter1 = data['SALEYEAR'] == 2015

# %%
result = data[filter1 & filter2]
result
# Out:
#        Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 19             19       3          1     Forced Air  Y          2      9
# 45             45       4          1      Warm Cool  Y          2      8
# 68             68       3          1      Warm Cool  Y          1      9
# 72             72       4          1  Hot Water Rad  Y          2      9
# 73             73       2          0      Warm Cool  Y          1      6
# ...           ...     ...        ...            ... ..        ...    ...
# 20375       20375       3          0     Forced Air  Y          1      8
# 20424       20424       4          1     Forced Air  Y          1      8
# 20487       20487       2          1     Forced Air  Y          1      9
# 20639       20639       2          1  Hot Water Rad  N          1      8
# 20708       20708       3          0     Forced Air  Y          1      8
#
#        BEDRM   AYB  YR_RMDL  ...  ASSESSMENT_SUBNBHD  CENSUS_TRACT  \
# 19         4  1890     2009  ...    040 E Old City 2          5201
# 45         4  1905     2008  ...    040 D Old City 2          4201
# 68         4  1908     2015  ...    040 D Old City 2          4201
# 72         4  1906     2007  ...    040 D Old City 2          4201
# 73         3  1939     2004  ...    040 D Old City 2          4202
# ...      ...   ...      ...  ...                 ...           ...
# 20375      3  1937     2014  ...      042 C Petworth          2202
# 20424      3  1937     2012  ...      042 C Petworth          2102
# 20487      3  1938     2015  ...      042 C Petworth          2202
# 20639      4  1937     2015  ...      042 C Petworth          2102
# 20708      3  1934     2014  ...      042 C Petworth          2102
#
#       CENSUS_BLOCK    WARD SQUARE          X          Y  QUADRANT SALEYEAR  \
# 19     005201 4003  Ward 2    208 -77.033366  38.911716        NW     2015
# 45     004201 1004  Ward 2    177 -77.037221  38.915033        NW     2015
# 68     004201 2005  Ward 2    152 -77.040429  38.914881        NW     2015
# 72     004201 2005  Ward 2    152 -77.040429  38.914881        NW     2015
# 73     004202 1008  Ward 2    134 -77.042719  38.912019        NW     2015
# ...            ...     ...    ...        ...        ...       ...      ...
# 20375  002202 1002  Ward 4   3402 -77.013210  38.950470        NW     2015
# 20424  002102 3003  Ward 4   3395 -77.012627  38.955059        NW     2015
# 20487  002202 1000  Ward 4   3404 -77.009298  38.951953        NW     2015
# 20639  002102 2006  Ward 4   3405 -77.011334  38.954966        NW     2015
# 20708  002102 2008  Ward 4   3397 -77.010450  38.953829        NW     2015
#
#       SALEMONTH
# 19            9
# 45           11
# 68            4
# 72            8
# 73           10
# ...         ...
# 20375         5
# 20424         7
# 20487         7
# 20639         7
# 20708         3
#
# [1040 rows x 45 columns]

# %%
result [['SALEYEAR','QUADRANT','FIREPLACES','PRICE']].groupby('FIREPLACES').mean().plot(figsize = (10,8), y = ['PRICE'], fontsize = 12, legend=True,
                                                                                      title = "Average Prices over Number of Fireplaces")

plt.ylabel('Sale Prices')
# Out:
# Text(0, 0.5, 'Sale Prices')

# %% [markdown]
# ## Good Luck!
